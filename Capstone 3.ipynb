# %% [markdown]
# ### **California Housing Price**
# [Sumber Data California Housing Price](https://drive.google.com/drive/folders/19YA_f36uGR86hTnZuX-Ech59s3AFzXXo)
# ### **Contents**
#
# 1. Business Problem Understanding
# 2. Data Understanding
# 3. Data Preprocessing
# 4. Modeling
# 5. Conclusion
# 6. Recommendation
#
# ****

# %% [markdown]
# ### **Business Problem Understanding**
# **Context**
#
# Pasar perumahan di California memainkan peran penting dalam perekonomian, namun juga menghadapi tantangan besar akibat fluktuasi harga yang terus terjadi. Berbagai faktor seperti lokasi geografis, aksesibilitas terhadap fasilitas umum, pendapatan masyarakat, dan dinamika pasar lokal memengaruhi harga rumah secara signifikan.
#
# Bagi pembeli, pengembang, dan agen real estate, memahami dan memperkirakan harga rumah dengan akurat menjadi prioritas untuk mendukung pengambilan keputusan strategis, baik untuk investasi maupun penentuan harga jual-beli. Namun, proses ini memiliki sejumlah hambatan, termasuk:
#
# - Kompleksitas variabel: Data yang melibatkan berbagai aspek seperti ukuran rumah, jumlah kamar, usia bangunan, dan karakteristik lingkungan membutuhkan analisis mendalam.
# - Efisiensi waktu: Metode manual dalam menentukan harga rumah sering memakan waktu lama dan rentan terhadap bias.
# - Variasi harga lokal: Perbedaan harga yang signifikan antara wilayah urban, suburban, dan rural memerlukan pendekatan yang kontekstual dan berbasis data.
#
# Selain itu, pasar perumahan California memiliki tantangan spesifik seperti permintaan tinggi di wilayah padat penduduk, ketimpangan daya beli antar komunitas, dan krisis keterjangkauan rumah akibat kenaikan harga yang melampaui pendapatan rata-rata. Untuk mengatasi masalah ini, pendekatan berbasis Machine Learning menjadi penting untuk membantu menemukan pola harga rumah secara otomatis dan akurat dengan memanfaatkan data historis.
#
# **Problem Statement**
#
# Bagaimana membangun sebuah model berbasis Machine Learning yang dapat memperkirakan harga rumah di California secara akurat berdasarkan berbagai faktor, seperti lokasi geografis, ukuran rumah, jumlah kamar, serta pendapatan rata-rata di lingkungan sekitarnya?
#
# Fluktuasi harga rumah yang tinggi menciptakan ketidakpastian bagi berbagai pemangku kepentingan dalam pasar properti. Tantangan ini menimbulkan dampak negatif seperti:
#
# - Kerugian finansial: Penetapan harga yang tidak akurat dapat merugikan pembeli maupun penjual rumah.
# - Peluang yang terlewatkan: Investor properti kesulitan memanfaatkan peluang pasar akibat kurangnya prediksi harga yang tepat.
# - Krisis keterjangkauan: Pembeli rumah sulit menentukan apakah suatu properti berada dalam jangkauan mereka, terutama di daerah dengan harga yang terus meningkat.
#
# Pendekatan tradisional yang bergantung pada estimasi manual tidak cukup untuk mengatasi dinamika kompleks pasar California. Dengan mengembangkan model prediktif berbasis Machine Learning, kita dapat:
#
# 1. Mengidentifikasi pola harga: Menganalisis hubungan antar variabel yang memengaruhi harga rumah secara sistematis.
# 2. Menyediakan prediksi akurat: Membantu pembeli, penjual, dan investor untuk mengambil keputusan berbasis data.
# 3. Meningkatkan efisiensi: Menghemat waktu dan tenaga dibandingkan metode tradisional.
#
# Tanpa solusi ini, pasar properti California akan terus menghadapi tantangan dalam memastikan keputusan yang tepat dan efisien di tengah fluktuasi harga yang signifikan.
#
# **Goals**
#
# 1. Membangun model regresi dengan performa akurasi tinggi dan dapat diandalkan.
# 2. Memberikan alat bantu bagi pembeli rumah, agen properti, dan pengembang real estate untuk memperkirakan harga rumah secara objektif.
# 3. Mendukung pengambilan keputusan strategis di pasar properti dengan analisis berbasis data.
#
# **Analysis Approach**
#
# Langkah-langkah yang akan dilakukan meliputi:
#
# 1. Eksplorasi data: Melakukan analisis untuk memahami pola, distribusi data, dan hubungan antar fitur, seperti lokasi, luas rumah, jumlah kamar, dan pendapatan lingkungan terhadap harga rumah.
# 2. Pra-pemrosesan data: Membersihkan dan mempersiapkan data, seperti menangani missing values, outliers, dan transformasi data jika diperlukan.
# 3. Pembangunan model regresi: Menggunakan algoritma regresi (seperti Linear Regression, Random Forest, atau Gradient Boosting) untuk memprediksi harga rumah berdasarkan fitur yang tersedia.
# 4. Optimasi model: Melakukan tuning hyperparameter untuk meningkatkan performa prediksi model.
# Hasil dari analisis ini akan digunakan untuk membangun tool prediksi harga rumah yang dapat membantu berbagai pemangku kepentingan dalam menetapkan harga yang kompetitif dan wajar.
#
# **Metric Evaluation**
#
# Evaluasi model akan menggunakan beberapa metrik, di antaranya:
#
# 1. Root Mean Squared Error (RMSE): Mengukur akar rata-rata kuadrat error, memberikan bobot lebih pada error yang besar.
# Mean Absolute Error (MAE): Mengukur rata-rata nilai absolut error, yang lebih mudah diinterpretasikan dalam skala harga rumah.
# 2. Mean Absolute Percentage Error (MAPE): Menunjukkan rata-rata persentase error, membantu memahami performa relatif model terhadap nilai sebenarnya.
# 3. R-squared (R²): Digunakan untuk mengevaluasi seberapa besar model mampu menjelaskan variansi dalam data (khusus untuk model linear).
#
# Semakin kecil nilai RMSE, MAE, dan MAPE, semakin baik model dalam memprediksi harga rumah. Sementara itu, nilai R² mendekati 1 menunjukkan model yang fit dengan data.

# %% [markdown]
# ### **Data Understanding**
#
# - Dataset merupakan data listing Harga Rumah di California pada tahun 1990 berdasarkan data sensus
# - Setiap baris data mewakili informasi sebuah distrik tertentu, yang mencakup berbagai karakteristik distrik tersebut, seperti lokasi geografis, kondisi perumahan, populasi, dan pendapatan penduduknya.
#
# **Attributes Information**
#
# | **Attribute** | **Data Type** | **Description** |
# | --- | --- | --- |
# | Longitude |  Float | Menunjukkan koordinat bujur lokasi distrik perumahan |
# | Latitude | Float | Menunjukkan koordinat lintang lokasi distrik perumahan |
# | Housing median age | Float | Usia median dari rumah-rumah di distrik tersebut (dalam tahun) |
# | Total_rooms | Float | Total jumlah kamar di semua rumah dalam distrik tersebut |
# | Total_bedrooms | Float | Total jumlah kamar tidur di semua rumah dalam distrik tersebut |
# | Population | Float | Jumlah total populasi yang tinggal di distrik tersebut |
# | Households | Float | Jumlah total rumah tangga yang ada di distrik tersebut |
# | Median_income | Float | Pendapatan median dari penduduk di distrik tersebut (dalam puluhan ribu dolar AS) |
# | Median house value | Object  | Nilai median dari rumah di distrik tersebut (dalam dolar AS) |
# | Ocean_proximity | Float | Kategori yang menunjukkan kedekatan lokasi distrik dengan laut |
#
# <br>

# %%
# Import library yang dibutuhkan untuk eksplorasi dataset
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# Load Dataset
df = pd.read_csv("data_california_house.csv")
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -119.79     36.73                52.0        112.0            28.0
# 1    -122.21     37.77                43.0       1017.0           328.0
# 2    -118.04     33.87                17.0       2358.0           396.0
# 3    -118.28     34.06                17.0       2518.0          1196.0
# 4    -119.81     36.73                50.0        772.0           194.0
#
#    population  households  median_income ocean_proximity  median_house_value
# 0       193.0        40.0         1.9750          INLAND             47500.0
# 1       836.0       277.0         2.2604        NEAR BAY            100000.0
# 2      1387.0       364.0         6.2990       <1H OCEAN            285800.0
# 3      3051.0      1000.0         1.7199       <1H OCEAN            175000.0
# 4       606.0       167.0         2.2206          INLAND             59200.0

# %% [markdown]
# #### **Exploratory Data Analysis**

# %% [markdown]
# **Understanding the data**

# %%
df.shape
# Out:
# (14448, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14448 entries, 0 to 14447
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           14448 non-null  float64
#  1   latitude            14448 non-null  float64
#  2   housing_median_age  14448 non-null  float64
#  3   total_rooms         14448 non-null  float64
#  4   total_bedrooms      14311 non-null  float64
#  5   population          14448 non-null  float64
#  6   households          14448 non-null  float64
#  7   median_income       14448 non-null  float64
#  8   ocean_proximity     14448 non-null  object
#  9   median_house_value  14448 non-null  float64
# dtypes: float64(9), object(1)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  14448.000000  14448.000000        14448.000000  14448.000000
# mean    -119.566647     35.630093           28.618702   2640.132683
# std        2.006587      2.140121           12.596694   2191.612441
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1451.000000
# 50%     -118.490000     34.260000           29.000000   2125.000000
# 75%     -118.000000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  32627.000000
#
#        total_bedrooms    population    households  median_income  \
# count    14311.000000  14448.000000  14448.000000   14448.000000
# mean       538.260709   1425.157323    499.508929       3.866667
# std        423.577544   1149.580157    383.098390       1.891158
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# **Melihat informasi Tipe data, data null, unique sample, data zero dan data negatif dari setiap  data feature**

# %%
listItem = []
for col in df.columns:
    listItem.append([
        col,
        df[col].dtype,
        df[col].isna().sum(),                        # Jumlah nilai null
        df[col].nunique(),                            # Jumlah nilai unik
        list(df[col].drop_duplicates().values[:5]),   # Sampel data unik (maksimal 5)
        (df[col] == 0).sum() if np.issubdtype(df[col].dtype, np.number) else 'N/A',  # Jumlah nilai 0 (jika numerik)
        (df[col] < 0).sum() if np.issubdtype(df[col].dtype, np.number) else 'N/A',   # Jumlah nilai negatif (jika numerik)
        df[col].duplicated().sum()                   # Jumlah duplikat
    ])

# Buat DataFrame deskriptif
dfDesc = pd.DataFrame(
    columns=['dataFeatures', 'dataType', 'null', 'unique', 'uniqueSample', 'zero', 'negative', 'duplicates'],
    data=listItem
)

print(df.shape)
dfDesc
# Out:
# (14448, 10)
#          dataFeatures dataType  null  unique  \
# 0           longitude  float64     0     806
# 1            latitude  float64     0     836
# 2  housing_median_age  float64     0      52
# 3         total_rooms  float64     0    5227
# 4      total_bedrooms  float64   137    1748
# 5          population  float64     0    3498
# 6          households  float64     0    1649
# 7       median_income  float64     0    9797
# 8     ocean_proximity   object     0       5
# 9  median_house_value  float64     0    3548
#
#                                         uniqueSample zero negative  duplicates
# 0      [-119.79, -122.21, -118.04, -118.28, -119.81]    0    14448       13642
# 1                 [36.73, 37.77, 33.87, 34.06, 33.8]    0        0       13612
# 2                     [52.0, 43.0, 17.0, 50.0, 11.0]    0        0       14396
# 3             [112.0, 1017.0, 2358.0, 2518.0, 772.0]    0        0        9221
# ...

# %%
# Menghitung jumlah baris duplikat
num_duplicates = df.duplicated().sum()
print(f"Jumlah baris duplikat: {num_duplicates}")
# Out:
# Jumlah baris duplikat: 0

# %% [markdown]
# Hal hal yang dapat disimpulkan berdasarkan informasi diatas:
# 1. Dari seluruh fitur, hanya ocean_proximity yang memiliki tipe object. Hal ini sudah sesuai dengan kebutuhan data saat ini, namun saat preprosessing perlu encode data ini.
# 2. Terdapat 137 data null pada kolom total_bedrooms. Jika dihitung persentasenya dari total row yang ada, maka data null ini kurang dari 1%, sehingga data ini dapat dihapus saja
# 3. Tidak ada data zero pada seluruh feature
# 4. Terdapat 14448 data minus pada kolom longitude. Secara data hal ini merupakan hal yang normal.
# 5. Pada dataset ini data duplikat tidak mempengaruhi hasil analisa dan tidak ada baris data yang duplikat

# %%
# Delete null data
df = df[df['total_bedrooms'].notnull()]

# %%
listItem = []
for col in df.columns:
    listItem.append([
        col,
        df[col].dtype,
        df[col].isna().sum(),                        # Jumlah nilai null
        df[col].nunique(),                            # Jumlah nilai unik
        list(df[col].drop_duplicates().values[:5]),   # Sampel data unik (maksimal 5)
        (df[col] == 0).sum() if np.issubdtype(df[col].dtype, np.number) else 'N/A',  # Jumlah nilai 0 (jika numerik)
        (df[col] < 0).sum() if np.issubdtype(df[col].dtype, np.number) else 'N/A',   # Jumlah nilai negatif (jika numerik)
        df[col].duplicated().sum()                   # Jumlah duplikat
    ])

# Buat DataFrame deskriptif
dfDesc = pd.DataFrame(
    columns=['dataFeatures', 'dataType', 'null', 'unique', 'uniqueSample', 'zero', 'negative', 'duplicates'],
    data=listItem
)

print(df.shape)
dfDesc
# Out:
# (14311, 10)
#          dataFeatures dataType  null  unique  \
# 0           longitude  float64     0     806
# 1            latitude  float64     0     835
# 2  housing_median_age  float64     0      52
# 3         total_rooms  float64     0    5213
# 4      total_bedrooms  float64     0    1748
# 5          population  float64     0    3491
# 6          households  float64     0    1646
# 7       median_income  float64     0    9726
# 8     ocean_proximity   object     0       5
# 9  median_house_value  float64     0    3540
#
#                                         uniqueSample zero negative  duplicates
# 0      [-119.79, -122.21, -118.04, -118.28, -119.81]    0    14311       13505
# 1                 [36.73, 37.77, 33.87, 34.06, 33.8]    0        0       13476
# 2                     [52.0, 43.0, 17.0, 50.0, 11.0]    0        0       14259
# 3             [112.0, 1017.0, 2358.0, 2518.0, 772.0]    0        0        9098
# ...

# %%
# Set the number of rows and columns for the subplot grid
n_cols = 4  # You can adjust this value based on your preferences
n_rows = len(df.select_dtypes(include=['float64', 'int64']).columns) // n_cols + 1

# Create a figure with subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 15))

# Flatten axes array for easy iteration
axes = axes.flatten()

# Loop over each numeric column and plot a boxplot
for i, col in enumerate(df.select_dtypes(include=['float64', 'int64']).columns):
    sns.boxplot(data=df, x=col, ax=axes[i])
    axes[i].set_title(f'Boxplot of {col}')

# Hide any unused subplots
for j in range(i + 1, len(axes)):
    axes[j].axis('off')

# Adjust the layout to avoid overlap
plt.tight_layout()
plt.show()

# %% [markdown]
# **Distribution of California house median house value**

# %%
# Plot distribusi fitur 
plt.figure(figsize=(7, 7))
sns.histplot(df['median_house_value'],kde=True)
plt.title('Median House Value Distribution Plot', size=15)
plt.show()

# %% [markdown]
# - Grafik menunjukkan bahwa sebagian besar nilai rumah berada pada rentang yang lebih rendah (antara 50.000 hingga 300.000).
# - Distribusi memiliki ekor panjang ke kanan, yang mengindikasikan beberapa nilai rumah yang lebih tinggi berada di ujung kanan grafik, namun jumlahnya lebih sedikit.
# - Ini adalah ciri khas distribusi **Positively skewed atau Right-Skewed**
# - Pada 500.000, terlihat adanya lonjakan nilai yang signifikan. Hal ini mengindikasikan bahwa nilai rumah capped atau dibatasi pada angka tertentu (mungkin akibat data sensus yang menetapkan batas atas median house value).
# Lonjakan ini bisa menunjukkan bahwa data mungkin memiliki censoring, di mana nilai di atas batas ini tidak direpresentasikan secara akurat.

# %%
# Drop rows where 'median_house_value' is equal to 500000
df = df[df['median_house_value'] < 500000]

# %%
# Plot distribusi fitur 
plt.figure(figsize=(7, 7))
sns.histplot(df['median_house_value'],kde=True)
plt.title('Median House Value Distribution Plot', size=15)
plt.show()

# %% [markdown]
# **Relasi antara median house value dan kolom lain**

# %%
import matplotlib.pyplot as plt

# List all columns except 'median_house_value'
columns = [col for col in df.columns if col != 'median_house_value']

# Create scatterplots for each column vs median_house_value
for col in columns:
    plt.figure(figsize=(8, 6))
    plt.scatter(df[col], df['median_house_value'], alpha=0.5, s=10, c='blue')
    plt.title(f"Scatter Plot of {col} vs Median House Value")
    plt.xlabel(col)
    plt.ylabel('Median House Value')
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.show()

# %%
# Find the row(s) with the maximum value in 'housing_median_age'
max_age_data = df[df['housing_median_age'] == df['housing_median_age'].max()]

# Display the result
print(max_age_data)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -119.79     36.73                52.0        112.0            28.0
# 38       -121.95     37.28                52.0        777.0           148.0
# 48       -122.43     37.71                52.0       1508.0           278.0
# 50       -122.26     37.88                52.0       2363.0           604.0
# 65       -122.25     37.84                52.0       3549.0           707.0
# ...          ...       ...                 ...          ...             ...
# 14331    -122.18     37.77                52.0       2744.0           547.0
# 14353    -122.41     37.74                52.0       2058.0           399.0
# 14378    -117.15     32.72                52.0        344.0           177.0
# 14424    -118.31     33.98                52.0       1837.0           426.0
# 14438    -122.43     37.75                52.0       2285.0           509.0
#
# ...

# %%
df.shape
# Out:
# (13621, 10)

# %% [markdown]
# Terdapat 758 data dengan max value 54 pada kolom housing median age. Hal ini mengindikasikan bahwa housing median age dibatasi pada angka tertentu. Dikarenakan data tersebut hanya 0.05% dari total data, sehingga tidak mempengaruhi analisa kita.

# %%
# Drop rows where 'housing_median_age' equals 52
df = df[df['housing_median_age'] != 52]

# %% [markdown]
# #### **Exploratory Data Analysis**

# %%
# Filter only numeric columns
numeric_df = df.select_dtypes(include=['number'])

# Calculate the correlation matrix for numeric columns
correlation_matrix = numeric_df.corr()

# Plot the heatmap
plt.figure(figsize=(15, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', cbar=True)
plt.title('Correlation Matrix of Numeric Columns')
plt.show()

# %% [markdown]
# Terdapat korelasi yang tinggi antara total_rooms, total_bedroom, population dan household.
# - Untuk kolom total_rooms, total_bedroom,household dapat diubah menjadi 2 kolom baru yaitu, total bedroom per household dan total room per household

# %%
## Creating useful features
df["rooms_per_household"] = df["total_rooms"]/df["households"]
df["bedrooms_per_household"] = df["total_bedrooms"]/df["households"]
df["population_per_household"] = df["population"]/df["households"]
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  12863.000000  12863.000000        12863.000000  12863.000000
# mean    -119.474619     35.586504           26.939905   2674.226463
# std        1.979545      2.149205           11.433244   2237.016782
# min     -124.300000     32.540000            1.000000      2.000000
# 25%     -121.530000     33.920000           17.000000   1460.000000
# 50%     -118.450000     34.240000           27.000000   2143.000000
# 75%     -117.970000     37.670000           36.000000   3182.000000
# max     -114.310000     41.950000           51.000000  32627.000000
#
#        total_bedrooms    population    households  median_income  \
# count    12863.000000  12863.000000  12863.000000   12863.000000
# mean       548.833865   1469.687398    509.007696       3.689751
# std        433.246296   1183.204266    392.469962       1.561784
# min          2.000000      3.000000      2.000000       0.499900
# ...

# %%
# Drop Column
df = df.drop(columns=['total_rooms', 'total_bedrooms' , 'households' , 'bedrooms_per_household'])

# Filter only numeric columns
numeric_df = df.select_dtypes(include=['number'])

# Calculate the correlation matrix for numeric columns
correlation_matrix = numeric_df.corr()

# Plot the heatmap
plt.figure(figsize=(15, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', cbar=True)
plt.title('Correlation Matrix of Numeric Columns')
plt.show()

# %%
#df1 = pd.read_excel("output.xlsx")
#df1.head()

# %%
#merged_df = df.merge(df1, how='left', on=['longitude', 'latitude'])
#merged_df.head()

# %%
#dropped kolom longitude dan latitude
#merged_df = merged_df.drop(columns=['longitude','latitude'])

# %%
#df = merged_df

# %% [markdown]
# Clean data

# %%
# Set the number of rows and columns for the subplot grid
n_cols = 4  # You can adjust this value based on your preferences
n_rows = len(df.select_dtypes(include=['float64', 'int64']).columns) // n_cols + 1

# Create a figure with subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 15))

# Flatten axes array for easy iteration
axes = axes.flatten()

# Loop over each numeric column and plot a boxplot
for i, col in enumerate(df.select_dtypes(include=['float64', 'int64']).columns):
    sns.boxplot(data=df, x=col, ax=axes[i])
    axes[i].set_title(f'Boxplot of {col}')

# Hide any unused subplots
for j in range(i + 1, len(axes)):
    axes[j].axis('off')

# Adjust the layout to avoid overlap
plt.tight_layout()
plt.show()

# %%
# Filter berdasarkan dua kondisi >> outlier extreme
df = df[(df['rooms_per_household'] <= 60) & (df['population_per_household'] <= 200)]

# %%
# Set the number of rows and columns for the subplot grid
n_cols = 4  # You can adjust this value based on your preferences
n_rows = len(df.select_dtypes(include=['float64', 'int64']).columns) // n_cols + 1

# Create a figure with subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 15))

# Flatten axes array for easy iteration
axes = axes.flatten()

# Loop over each numeric column and plot a boxplot
for i, col in enumerate(df.select_dtypes(include=['float64', 'int64']).columns):
    sns.boxplot(data=df, x=col, ax=axes[i])
    axes[i].set_title(f'Boxplot of {col}')

# Hide any unused subplots
for j in range(i + 1, len(axes)):
    axes[j].axis('off')

# Adjust the layout to avoid overlap
plt.tight_layout()
plt.show()

# %%
# Create the boxplot
sns.boxplot(x='ocean_proximity', y='median_house_value', data=df)

# Set the plot title and labels
plt.title('Boxplot of Median house value by Ocean Proximity')
plt.xlabel('Ocean Proximity')
plt.ylabel('Median house value')
# Out:
# Text(0, 0.5, 'Median house value')

# %% [markdown]
# # Modelling data

# %%
# Import library untuk modeling

from sklearn.model_selection import train_test_split, cross_val_score, RandomizedSearchCV, GridSearchCV, KFold

import category_encoders as ce
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost.sklearn import XGBRegressor
from sklearn.compose import TransformedTargetRegressor

from sklearn.preprocessing import StandardScaler

from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

# %%
# Memisahkan data independen variabel dengan target
X = df.drop(['median_house_value'], axis=1)
y = df['median_house_value']

# %%
# Splitting data training dan test dengan proporsi 70:30
X_train, X_test, y_train, y_test= train_test_split(
    X,
    y,  
    test_size=0.3,
    random_state=1)
y_train
# Out:
# 4594      84600.0
# 7496     208600.0
# 3102     208000.0
# 1928      93400.0
# 7897     148200.0
#            ...
# 12313     49500.0
# 998      207400.0
# 5822     233300.0
# 13674    236100.0
# 259      130600.0
# Name: median_house_value, Length: 9001, dtype: float64

# %%
y_train_df = y_train.to_frame(name="median_house_value")
print(y_train_df.columns)
# Out:
# Index(['median_house_value'], dtype='object')

# %%
df['ocean_proximity'].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     5748
# INLAND        4406
# NEAR OCEAN    1616
# NEAR BAY      1088
# ISLAND           1
# Name: count, dtype: int64

# %%
# Define algoritma yang digunakan
lr = LinearRegression()
knn = KNeighborsRegressor()
dt = DecisionTreeRegressor(random_state=1)
rf = RandomForestRegressor(random_state=1)
xgb = XGBRegressor(random_state=1)

# %%
# Daftar kolom numerik yang ingin discale
numeric_features = ['housing_median_age', 'population', 'median_income'
                   , 'rooms_per_household', 'population_per_household']

# ColumnTransformer untuk OneHotEncoder dan Scaling data numerik
transformer = ColumnTransformer([
    ('One Hot', OneHotEncoder(handle_unknown='ignore', drop='first'), ['ocean_proximity']),
    ('Scaler', StandardScaler(), numeric_features),
], remainder='passthrough')

# %%
df
# Out:
#        longitude  latitude  housing_median_age  population  median_income  \
# 1        -122.21     37.77                43.0       836.0         2.2604
# 2        -118.04     33.87                17.0      1387.0         6.2990
# 3        -118.28     34.06                17.0      3051.0         1.7199
# 4        -119.81     36.73                50.0       606.0         2.2206
# 5        -117.79     33.80                11.0      4409.0         6.6700
# ...          ...       ...                 ...         ...            ...
# 14442    -120.06     36.94                19.0       700.0         2.2375
# 14443    -121.26     38.27                20.0       712.0         4.4125
# 14444    -120.89     37.48                27.0       647.0         2.9135
# 14446    -117.93     33.62                34.0      1052.0         5.6315
# 14447    -115.56     32.80                15.0      1024.0         1.3882
#
#       ocean_proximity  median_house_value  rooms_per_household  \
# ...

# %%
transformer
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('One Hot',
#                                  OneHotEncoder(drop='first',
#                                                handle_unknown='ignore'),
#                                  ['ocean_proximity']),
#                                 ('Scaler', StandardScaler(),
#                                  ['housing_median_age', 'population',
#                                   'median_income', 'rooms_per_household',
#                                   'population_per_household'])])

# %%
# Menambahkan nama kolom agar target tetap terstruktur dengan baik
y_train_df = y_train.to_frame()  # Mengubah y_train menjadi DataFrame dengan nama kolom

# Model dengan transformasi logaritma
log_lr = TransformedTargetRegressor(lr, func=np.log, inverse_func=np.exp)
log_knn = TransformedTargetRegressor(knn, func=np.log, inverse_func=np.exp)
log_dt = TransformedTargetRegressor(dt, func=np.log, inverse_func=np.exp)
log_rf = TransformedTargetRegressor(rf, func=np.log, inverse_func=np.exp)
log_xgb = TransformedTargetRegressor(xgb, func=np.log, inverse_func=np.exp)



# Fit model dengan y_train_df yang sudah memiliki kolom
log_lr.fit(X_train, y_train_df)
log_knn.fit(X_train, y_train_df)
log_dt.fit(X_train, y_train_df)
log_rf.fit(X_train, y_train_df)
log_xgb.fit(X_train, y_train_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14216\1483795754.py in ?()
#      10
#      11
#      12
#      13 # Fit model dengan y_train_df yang sudah memiliki kolom
# ---> 14 log_lr.fit(X_train, y_train_df)
#      15 log_knn.fit(X_train, y_train_df)
#      16 log_dt.fit(X_train, y_train_df)
#      17 log_rf.fit(X_train, y_train_df)
#
# c:\Users\sys.analyst2\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1385                 skip_parameter_validation=(
#    1386                     prefer_skip_nested_validation or global_skip_validation
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#
# ...

# %%
pip install --upgrade scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Kandidat algoritma
models = [log_lr, log_knn, log_dt, log_rf, log_xgb]

score_rmse = []
nilai_mean_rmse = []
nilai_std_rmse = []

score_mae = []
nilai_mean_mae = []
nilai_std_mae = []

score_mape = []
nilai_mean_mape = []
nilai_std_mape = []

# Mencari algoritma terbaik berdasarkan tiap metrics
for model in models:
    try:
        estimator = Pipeline([
            ('preprocessing', transformer),
            ('model', model)
        ])
        estimator.fit(X_train[:10], y_train[:10])  # Menggunakan subset kecil untuk uji coba
        print(f"Model {model} kompatibel.")
    except Exception as e:
        print(f"Model {model} tidak kompatibel. Error: {e}")

    # RMSE
    model_cv_rmse = cross_val_score(
        estimator, 
        X_train, 
        y_train, 
        cv=5, 
        scoring='neg_root_mean_squared_error', 
        error_score='raise'
    )

    score_rmse.append(model_cv_rmse)
    nilai_mean_rmse.append(model_cv_rmse.mean())
    nilai_std_rmse.append(model_cv_rmse.std())

    # MAE
    model_cv_mae = cross_val_score(
        estimator, 
        X_train, 
        y_train, 
        cv=5, 
        scoring='neg_mean_absolute_error', 
        error_score='raise'
    )

    score_mae.append(model_cv_mae)
    nilai_mean_mae.append(model_cv_mae.mean())
    nilai_std_mae.append(model_cv_mae.std())

    # MAPE
    model_cv_mape = cross_val_score(
        estimator, 
        X_train, 
        y_train, 
        cv=5, 
        scoring='neg_mean_absolute_percentage_error', 
        error_score='raise'
    )

    score_mape.append(model_cv_mape)
    nilai_mean_mape.append(model_cv_mape.mean())
    nilai_std_mape.append(model_cv_mape.std())
# Out:
# Model TransformedTargetRegressor(func=<ufunc 'log'>, inverse_func=<ufunc 'exp'>,
#                            regressor=LinearRegression()) kompatibel.
# Model TransformedTargetRegressor(func=<ufunc 'log'>, inverse_func=<ufunc 'exp'>,
#                            regressor=KNeighborsRegressor()) kompatibel.
# Model TransformedTargetRegressor(func=<ufunc 'log'>, inverse_func=<ufunc 'exp'>,
#                            regressor=DecisionTreeRegressor(random_state=1)) kompatibel.
# Model TransformedTargetRegressor(func=<ufunc 'log'>, inverse_func=<ufunc 'exp'>,
#                            regressor=RandomForestRegressor(random_state=1)) kompatibel.
# Model TransformedTargetRegressor(func=<ufunc 'log'>, inverse_func=<ufunc 'exp'>,
#                            regressor=XGBRegressor(base_score=None, booster=None,
#                                                   callbacks=None,
#                                                   colsample_bylevel=None,
# ...

# %%
# Find the best model based on each metric
best_model_rmse = models[np.argmax([i.mean() for i in score_rmse])]
best_model_mae = models[np.argmax([i.mean() for i in score_mae])]
best_model_mape = models[np.argmax([i.mean() for i in score_mape])]

print("Best model based on RMSE:", best_model_rmse)
print("Best model based on MAE:", best_model_mae)
print("Best model based on MAPE:", best_model_mape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 2
#       1 # Find the best model based on each metric
# ----> 2 best_model_rmse = models[np.argmax([i.mean() for i in score_rmse])]
#       3 best_model_mae = models[np.argmax([i.mean() for i in score_mae])]
#       4 best_model_mape = models[np.argmax([i.mean() for i in score_mape])]
#
# File c:\Users\sys.analyst2\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\_core\fromnumeric.py:1359, in argmax(a, axis, out, keepdims)
#    1270 """
#    1271 Returns the indices of the maximum values along an axis.
#    1272
#    (...)
#    1356 (2, 1, 4)
#    1357 """
#    1358 kwds = {'keepdims': keepdims} if keepdims is not np._NoValue else {}
# -> 1359 return _wrapfunc(a, 'argmax', axis=axis, out=out, **kwds)
#
# ...
